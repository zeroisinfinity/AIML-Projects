# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import kagglehub

path = kagglehub.dataset_download("msambare/fer2013")
target_emotions = ['angry', 'happy', 'sad']

full_ds = keras.utils.image_dataset_from_directory(
    path + '/train',
    class_names=target_emotions,
    image_size=(48, 48),
    batch_size=32,
    color_mode='grayscale'
)

train_ds = full_ds.take(20).cache().prefetch(buffer_size=tf.data.AUTOTUNE)


model = keras.Sequential([
    layers.Input(shape=(48, 48, 1)),
    layers.Rescaling(1./255),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(3, activation='softmax')
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(train_ds, epochs=15)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# Found 16040 files belonging to 3 classes.
# Epoch 1/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4563 - loss: 1.0771
# Epoch 2/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.4594 - loss: 1.0600
# Epoch 3/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.4656 - loss: 1.0446
# Epoch 4/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.4750 - loss: 1.0132
# Epoch 5/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.5156 - loss: 0.9718
# Epoch 6/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5641 - loss: 0.9253
# Epoch 7/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6109 - loss: 0.8697
# Epoch 8/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.6594 - loss: 0.8142
# Epoch 9/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6922 - loss: 0.7566
# Epoch 10/15
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.7188 - loss: 0.7070
# ...

# %%
# use open cv to take live feed n identify faces
for images, labels in train_ds.take(1):
    predictions = model.predict(images[:5])
    for i in range(5):
        predicted_label = target_emotions[np.argmax(predictions[i])]
        actual_label = target_emotions[labels[i]]
        print(f"Image {i+1}: Predicted : {predicted_label} (Actual: {actual_label})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image 1: Predicted : sad (Actual: sad)
# Image 2: Predicted : angry (Actual: angry)
# Image 3: Predicted : happy (Actual: happy)
# Image 4: Predicted : sad (Actual: sad)
# Image 5: Predicted : angry (Actual: angry)
